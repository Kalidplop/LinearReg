# %%
from sklearn import linear_model
import matplotlib.pyplot as pyplot
import numpy as np

data=np.array([
    [0.05,0.12],
    [0.18,0.22],
    [0.31,0.35],
    [0.42,0.38],
    [0.50,0.49]])

X, y=data[:,0],data[:,1]
X= X.reshape((len(X),1))

lr=linear_model.LinearRegression()
lr.fit(X,y)

yhat=lr.predict(X)

pyplot.scatter(X,y)
pyplot.plot(X,yhat,color="red")

pyplot.show()

# %%
lr.predict([[0.35]])
# Out:
# array([0.35765487])

# %%
import pandas as pd
df=pd.read_excel("Formulario sin título (respuestas).xlsx")
df
# Out:
#             Marca temporal  Peso  Altura
# 0  2020-02-24 18:15:40.377   100     180
# 1  2020-02-24 18:55:12.631    68     170
# 2  2020-02-24 18:55:26.376    65     169
# 3  2020-02-24 18:55:35.802    75     174
# 4  2020-02-24 18:55:46.441    75     185
# 5  2020-02-24 18:55:53.148    76     177
# 6  2020-02-24 18:55:57.894    75     189
# 7  2020-02-24 18:56:00.000    68     174
# 8  2020-02-24 18:56:24.840    61     162
# 9  2020-02-24 18:57:03.105    67     171
# 10 2020-02-24 18:57:24.977    52     168
# 11 2020-02-24 18:57:42.827    60     168
# 12 2020-02-24 18:58:14.252    68     174

# %%
df["Peso"].values
X, y=df["Peso"].values,df["Altura"].values
X= X.reshape((len(X),1))

lr=linear_model.LinearRegression()
lr.fit(X,y)

yhat=lr.predict(X)

pyplot.scatter(X,y)
pyplot.plot(X,yhat,color="red")

pyplot.show()

# %%
# !dir
# Out:
#  El volumen de la unidad C es Windows
#  El n£mero de serie del volumen es: 5C8C-91C0
#
#  Directorio de C:\Users\kalid\1Python
#
# 24/02/2020  07:24 p. m.    <DIR>          .
# 24/02/2020  07:24 p. m.    <DIR>          ..
# 24/02/2020  06:36 p. m.    <DIR>          .ipynb_checkpoints
# 24/02/2020  07:00 p. m.             5,222 Formulario sin t¡tulo (respuestas).xlsx
# 27/01/2020  06:06 p. m.            25,450 FuncionesMod.ipynb
# 10/02/2020  08:05 p. m.         1,160,314 ploteando y simboleando.ipynb
# 20/01/2020  08:50 p. m.             4,865 Principios.ipynb
# 17/02/2020  08:01 p. m.            39,096 prograLineal.ipynb
# 24/02/2020  07:24 p. m.            30,932 Regresi¢n lineal.ipynb
# 24/02/2020  07:20 p. m.    <DIR>          Robotica_2020-master
# 21/01/2020  06:21 p. m.             1,850 Tarea1.ipynb
# 27/01/2020  07:52 p. m.             6,131 Vectores.ipynb
# 27/01/2020  05:14 p. m.             1,291 Ver archivo.ipynb
# 17/02/2020  06:18 p. m.               492 WhiskasModel.lp
#               10 archivos      1,275,643 bytes
#                4 dirs  60,495,044,608 bytes libres

# %%
#1
names = ["Fecha","Nombre", "Dependencia", "Puesto", "Estatus", "Tipo", "Percepciones","Deducciones", "Neto"]
df = pd.read_csv("https://raw.githubusercontent.com/RoboticaIndustrial/Robotica_2020/master/NominaJalisco/nomina_0_3000.csv", names=names, header = None)
df.head()
# Out:
#         Fecha                            Nombre  \
# 0       Fecha                   Nombre Empleado
# 1  13/02/2020    BECERRA CALVILLO MARIA BEATRIZ
# 2  13/02/2020             BUENO ESTRADA YESENIA
# 3  13/02/2020  BUENROSTRO PRIETO ERNESTO ALONSO
# 4  13/02/2020     BUENROSTRO PRIETO KARLA MARIA
#
#                          Dependencia                    Puesto       Estatus  \
# 0                        Dependencia                    Puesto  Percepciones
# 1  SECRETARÍA DE LA HACIENDA PÚBLICA                   CAJERO         ACTIVO
# 2  SECRETARÍA DE LA HACIENDA PÚBLICA                   CAJERO         ACTIVO
# 3  SECRETARÍA DE LA HACIENDA PÚBLICA               ANALISTA B         ACTIVO
# 4  SECRETARÍA DE LA HACIENDA PÚBLICA  AUXILIAR ADMINISTRATIVO         ACTIVO
#
#           Tipo Percepciones  Deducciones     Neto
# 0  Deducciones         Neto          NaN      NaN
# 1         BASE      2508.46       518.70  1989.76
# 2         BASE      2508.46       518.70  1989.76
# 3         BASE      2508.46       518.70  1989.76
# 4         BASE      2006.78       411.54  1595.24

# %%
#2
names = ["Fecha","Nombre", "Dependencia", "Puesto", "Estatus", "Tipo", "Percepciones","Deducciones", "Neto"]
df = pd.read_csv("https://raw.githubusercontent.com/RoboticaIndustrial/Robotica_2020/master/NominaJalisco/nomina_10001_.csv", names=names, header = None)
df.head()
# Out:
#         Fecha                              Nombre  \
# 0       Fecha                     Nombre Empleado
# 1  11/02/2020  CUEVAS HERNANDEZ MONICA DEL CARMEN
# 2  11/02/2020         VEGA DIAZ OCTAVIO EIPOYUCAN
# 3  11/02/2020               HERNANDEZ COBA ADRIAN
# 4  11/02/2020    GONZALEZ MARTINEZ CARLOS ALBERTO
#
#                             Dependencia  \
# 0                           Dependencia
# 1     SECRETARÍA DE LA HACIENDA PÚBLICA
# 2                   FISCALÍA DEL ESTADO
# 3              SECRETARÍA DE TRANSPORTE
# 4  SECRETARÍA PARTICULAR DEL GOBERNADOR
#
#                                               Puesto       Estatus  \
# 0                                             Puesto  Percepciones
# 1                                 PERSONAL EVENTUAL       INACTIVO
# 2                                             LAUDO       INACTIVO
# 3                                             LAUDO         ACTIVO
# 4  DIRECTOR DE COMUNICACION DE LA COORDINACION GE...        ACTIVO
#
#           Tipo Percepciones  Deducciones       Neto
# 0  Deducciones         Neto          NaN        NaN
# 1         BASE      19850.0      3837.97   16012.03
# 2         BASE    174751.38     77345.38   97406.00
# 3         BASE     230000.0         0.00  230000.00
# 4         BASE      29322.5      9849.75   19472.75

# %%
#4
names = ["Fecha","Nombre", "Dependencia", "Puesto", "Estatus", "Tipo", "Percepciones","Deducciones", "Neto"]
df=pd.read_csv("https://raw.githubusercontent.com/RoboticaIndustrial/Robotica_2020/master/NominaJalisco/nomina_3001_4000.csv", names=names, header = None)
df.head()
# Out:
#         Fecha                              Nombre  \
# 0       Fecha                     Nombre Empleado
# 1  13/02/2020  HERNANDEZ GUTIERREZ ALDO ALEJANDRO
# 2  13/02/2020        CONTRERAS MENDOZA DORA ELENA
# 3  13/02/2020               MENA CHAVEZ LUZ MARIA
# 4  13/02/2020          CONTRERAS GUERRERO DOMINGO
#
#                          Dependencia                        Puesto  \
# 0                        Dependencia                        Puesto
# 1  SECRETARÍA DE LA HACIENDA PÚBLICA  JEFE DE OFICINA RECAUDADORA
# 2  SECRETARÍA DE LA HACIENDA PÚBLICA            JEFE DE OFICINA A
# 3  SECRETARÍA DE LA HACIENDA PÚBLICA                       CAJERO
# 4  SECRETARÍA DE LA HACIENDA PÚBLICA              EJECUTOR FISCAL
#
#         Estatus         Tipo Percepciones  Deducciones     Neto
# 0  Percepciones  Deducciones         Neto          NaN      NaN
# 1        ACTIVO         BASE      5016.94      1140.64  3876.30
# 2        ACTIVO         BASE      5016.94      1054.50  3962.44
# 3        ACTIVO         BASE      4013.54       840.18  3173.36
# 4        ACTIVO         BASE      4515.22       947.34  3567.88

# %%
#5
names = ["Fecha","Nombre", "Dependencia", "Puesto", "Estatus", "Tipo", "Percepciones","Deducciones", "Neto"]
df=pd.read_csv("https://raw.githubusercontent.com/RoboticaIndustrial/Robotica_2020/master/NominaJalisco/nomina_4001_4500.csv", names=names, header = None)
df.head()
# Out:
#         Fecha                           Nombre  \
# 0       Fecha                  Nombre Empleado
# 1  13/02/2020          LAMAS MEZA HUGO ERNESTO
# 2  13/02/2020      IBARRA LUNA CARLOS HUMBERTO
# 3  13/02/2020     PACHECO IBARRA CARLOS ISRAEL
# 4  13/02/2020  GONZALEZ MELO ARMINDA ERNESTINA
#
#                          Dependencia  \
# 0                        Dependencia
# 1  SECRETARÍA DE LA HACIENDA PÚBLICA
# 2  SECRETARÍA DE LA HACIENDA PÚBLICA
# 3  SECRETARÍA DE LA HACIENDA PÚBLICA
# 4  SECRETARÍA DE LA HACIENDA PÚBLICA
#
#                                               Puesto       Estatus  \
# 0                                             Puesto  Percepciones
# 1              JEFE DE DEPARTAMENTO DE NOTIFICACION         ACTIVO
# 2        COORDINADOR DE RECAUDACION METROPOLITANA B         ACTIVO
# 3  DIRECTOR DE INGRESOS AUTOMATIZADOS Y CONTROL V...        ACTIVO
# 4         COORDINADOR DE SERVICIOS AL CONTRIBUYENTE         ACTIVO
#
#           Tipo Percepciones  Deducciones     Neto
# 0  Deducciones         Neto          NaN      NaN
# 1         BASE      5518.62      1273.98  4244.64
# 2         BASE      6522.02      1900.08  4621.94
# 3         BASE      6522.02      1900.08  4621.94
# 4         BASE      5518.62      1273.98  4244.64

# %%
#6
names = ["Fecha","Nombre", "Dependencia", "Puesto", "Estatus", "Tipo", "Percepciones","Deducciones", "Neto"]
df=pd.read_csv("https://raw.githubusercontent.com/RoboticaIndustrial/Robotica_2020/master/NominaJalisco/nomina_4901_4999.csv", names=names, header = None)
df.head()
# Out:
#         Fecha                          Nombre  \
# 0       Fecha                 Nombre Empleado
# 1  10/02/2020  ROSTRO BRICIO ALVARO FRANCISCO
# 2  10/02/2020        SILVA ALVAREZ ROSA ELENA
# 3  06/02/2020    VIVAR RODRIGUEZ MARTHA ROCIO
# 4  06/02/2020   ZARATE CARREON HUGO ALEJANDRO
#
#                                          Dependencia  \
# 0                                        Dependencia
# 1                  SECRETARÍA DE LA HACIENDA PÚBLICA
# 2                  SECRETARÍA DE LA HACIENDA PÚBLICA
# 3                  SECRETARÍA DE LA HACIENDA PÚBLICA
# 4  SECRETARÍA DE MEDIO AMBIENTE Y DESARROLLO TERR...
#
#                         Puesto       Estatus         Tipo Percepciones  \
# 0                       Puesto  Percepciones  Deducciones         Neto
# 1          NOTIFICADOR FISCAL         ACTIVO         BASE      11046.0
# 2          NOTIFICADOR FISCAL       INACTIVO         BASE      10450.8
# 3  SUPERVISOR DE AREA TECNICA         ACTIVO         BASE       6272.5
# 4                 COMBATIENTE         ACTIVO         BASE       7166.0
#
#    Deducciones     Neto
# 0          NaN      NaN
# 1      6113.54  4932.46
# 2      5471.96  4978.84
# 3      1337.01  4935.49
# 4      2214.45  4951.55

# %%
#7
names = ["Fecha","Nombre", "Dependencia", "Puesto", "Estatus", "Tipo", "Percepciones","Deducciones", "Neto"]
df =pd.read_csv("https://raw.githubusercontent.com/RoboticaIndustrial/Robotica_2020/master/NominaJalisco/nomina_5001_7000.csv", names=names, header = None)
df.head()
# Out:
#         Fecha                           Nombre  \
# 0       Fecha                  Nombre Empleado
# 1  11/02/2020  VAZQUEZ VELAZQUEZ BERTHA ALICIA
# 2  11/02/2020              GARCIA NUÑO VIOLETA
# 3  10/02/2020          BARRAGAN RIVERA ANTONIO
# 4  10/02/2020         CARCAMO MONTES JOSE LUIS
#
#                          Dependencia  \
# 0                        Dependencia
# 1  SECRETARÍA DE LA HACIENDA PÚBLICA
# 2                FISCALÍA DEL ESTADO
# 3  SECRETARÍA DE LA HACIENDA PÚBLICA
# 4  SECRETARÍA DE LA HACIENDA PÚBLICA
#
#                                           Puesto       Estatus         Tipo  \
# 0                                         Puesto  Percepciones  Deducciones
# 1                             PERSONAL EVENTUAL       INACTIVO         BASE
# 2  SECRETARIO DE AGENCIA DEL MINISTERIO PUBLICO         ACTIVO         BASE
# 3                               EJECUTOR FISCAL       INACTIVO         BASE
# 4                               EJECUTOR FISCAL       INACTIVO         BASE
#
#   Percepciones  Deducciones     Neto
# 0         Neto          NaN      NaN
# 1       5800.0       604.95  5195.05
# 2       8544.0      2053.92  6490.08
# 3     12454.37      6664.69  5789.68
# 4     12454.37      6353.69  6100.68

# %%
#8
names = ["Fecha","Nombre", "Dependencia", "Puesto", "Estatus", "Tipo", "Percepciones","Deducciones", "Neto"]
df =pd.read_csv("https://raw.githubusercontent.com/RoboticaIndustrial/Robotica_2020/master/NominaJalisco/nomina_7000_10000.csv", names=names, header = None)
df.head()
# Out:
#         Fecha                           Nombre  \
# 0       Fecha                  Nombre Empleado
# 1  10/02/2020     RAMOS PALACIOS LUIS FERNANDO
# 2  10/02/2020   MORALES PEREZ ALEJANDRO RAFAEL
# 3  10/02/2020        ORIZAGA CRUZ JONATHAN ZOE
# 4  10/02/2020  RIVERA ESPINOZA OSCAR GUILLERMO
#
#                          Dependencia               Puesto       Estatus  \
# 0                        Dependencia               Puesto  Percepciones
# 1  SECRETARÍA DE LA HACIENDA PÚBLICA  NOTIFICADOR FISCAL         ACTIVO
# 2  SECRETARÍA DE LA HACIENDA PÚBLICA  NOTIFICADOR FISCAL       INACTIVO
# 3  SECRETARÍA DE LA HACIENDA PÚBLICA  NOTIFICADOR FISCAL         ACTIVO
# 4  SECRETARÍA DE LA HACIENDA PÚBLICA  NOTIFICADOR FISCAL         ACTIVO
#
#           Tipo Percepciones  Deducciones     Neto
# 0  Deducciones         Neto          NaN      NaN
# 1         BASE      11227.2      4178.09  7049.11
# 2         BASE      17832.0      8024.44  9807.56
# 3         BASE      13854.0      6232.73  7621.27
# 4         BASE      15379.8      7165.68  8214.12

# %%
df.describe()
# Out:
#         Deducciones         Neto
# count   1096.000000  1096.000000
# mean    4209.109754  8211.640119
# std     3972.626771   806.193493
# min      839.500000  7000.090000
# 25%     2487.200000  7392.300000
# 50%     2971.070000  8301.050000
# 75%     3664.765000  9173.310000
# max    59440.920000  9997.490000

# %%
NominaList = ["https://raw.githubusercontent.com/RoboticaIndustrial/Robotica_2020/master/NominaJalisco/nomina_0_3000.csv",
             "https://raw.githubusercontent.com/RoboticaIndustrial/Robotica_2020/master/NominaJalisco/nomina_10001_.csv",
             "https://raw.githubusercontent.com/RoboticaIndustrial/Robotica_2020/master/NominaJalisco/nomina_3001_4000.csv",
             "https://raw.githubusercontent.com/RoboticaIndustrial/Robotica_2020/master/NominaJalisco/nomina_4001_4500.csv",
             "https://raw.githubusercontent.com/RoboticaIndustrial/Robotica_2020/master/NominaJalisco/nomina_4901_4999.csv",
             "https://raw.githubusercontent.com/RoboticaIndustrial/Robotica_2020/master/NominaJalisco/nomina_5001_7000.csv",
             "https://raw.githubusercontent.com/RoboticaIndustrial/Robotica_2020/master/NominaJalisco/nomina_7000_10000.csv"]
mi_df = lambda x: pd.read_csv(x,usecols = [1,2,3,4,5,6,7,8],names=names,header=None,skiprows=2)

df_from_each_file = (mi_df(f) for f in NominaList)
nomina = pd.concat(df_from_each_file,ignore_index=True)
nomina.head()
# Out:
#                              Nombre                        Dependencia  \
# 0    BECERRA CALVILLO MARIA BEATRIZ  SECRETARÍA DE LA HACIENDA PÚBLICA
# 1             BUENO ESTRADA YESENIA  SECRETARÍA DE LA HACIENDA PÚBLICA
# 2  BUENROSTRO PRIETO ERNESTO ALONSO  SECRETARÍA DE LA HACIENDA PÚBLICA
# 3     BUENROSTRO PRIETO KARLA MARIA  SECRETARÍA DE LA HACIENDA PÚBLICA
# 4   CARDENAS ANTOLIN CARMEN FABIOLA  SECRETARÍA DE LA HACIENDA PÚBLICA
#
#                      Puesto Estatus  Tipo  Percepciones  Deducciones     Neto
# 0                   CAJERO   ACTIVO  BASE       2508.46       518.70  1989.76
# 1                   CAJERO   ACTIVO  BASE       2508.46       518.70  1989.76
# 2               ANALISTA B   ACTIVO  BASE       2508.46       518.70  1989.76
# 3  AUXILIAR ADMINISTRATIVO   ACTIVO  BASE       2006.78       411.54  1595.24
# 4                   CAJERO   ACTIVO  BASE       2508.46       518.70  1989.76

# %%
nomina.plot.scatter("Percepciones","Deducciones",figsize=(12,9))

# %%
X, y = nomina["Percepciones"].values, nomina["Deducciones"].values
X = X.reshape((len(X),1))

lr = linear_model.LinearRegression()
lr.fit(X,y)
#predict
yhat = lr.predict(X)

#plot data and predictions
plt.figure(figsize=(12,9))
plt.scatter(X,y)
plt.plot(X,yhat,color='red')

plt.show()

# %%
import matplotlib.pyplot as plt
